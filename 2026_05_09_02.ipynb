# %% [markdown]
# <a href="https://colab.research.google.com/github/LINLCLCC/_2026_05_09_chihlee_python_/blob/main/2026_05_09_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(2 + 3 * 4 )
print(2 + 12)
print(14)
# Out:
# 14
# 14
# 14
