# %% [markdown]
# <a href="https://colab.research.google.com/github/LINLCLCC/_2026_05_09_chihlee_python_/blob/main/05_09/026_05_09_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n =int (input("請輸入一個整數"))
print(n)
type(n)
# Out:
# 請輸入一個整數90
# 90
# int
