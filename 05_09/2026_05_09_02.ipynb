# %% [markdown]
# <a href="https://colab.research.google.com/github/LINLCLCC/_2026_05_09_chihlee_python_/blob/main/05_09/2026_05_09_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 字串的操作
print('Snap')
print("Crakle")
print("'Nay' said the naysyer")
# Out:
# Snap
# Crakle
# 'Nay' said the naysyer

# %%
#多行文字
print('''Boom!\n Eek''')
# Out:
# Boom!
#  Eek
